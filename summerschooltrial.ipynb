# %% [markdown]
# <a href="https://colab.research.google.com/github/samzonli/planets/blob/main/summerschooltrial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# This is my comment line.

# %% [markdown]
# # Hello World
# ## This is fun
# This is my *first* code in Python

# %% [markdown]
# This is my comment line.

# %%
print("Hello World")
# Out:
# Hello World
